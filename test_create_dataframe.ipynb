# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://inventory.data.gov/dataset/8bf56e54-1a05-4726-9c20-cfd22a20c48d/resource/474b78a0-37c2-4d79-877f-05025428ae57/download/userssharedsdfpromiseneighborhoods2011applications.csv")
# Out:
#                                            Applicant      Grant Type  \
# 0         African American Empowerment Network, Inc.        Planning
# 1              Alliance for a Better Community (ABC)        Planning
# 2                                      ALU LIKE, Inc        Planning
# 3  American Pacific Islands Center for Educationa...        Planning
# 4                       Amherst H. Wilder Foundation  Implementation
#
#   Applicant Type Absolute Priority  \
# 0     Non Profit              AP 1
# 1     Non Profit              AP 1
# 2     Non Profit              AP 2
# 3     Non Profit              AP 1
# 4     Non Profit              AP 1
#
#                                                 City State  Zip Code  \
# 0                                              Omaha    NE   68110.0
# 1                                        Los Angeles    CA   90005.0
# 2  Hana on Maui island and Molokai (island wide n...    HI   96713.0
# 3                                             Carson    CA   90745.0
# 4                                         Saint Paul    MN   55104.0
#
#                                        Project Title  CP4  CP5  ...  \
# 0  North Omaha Village Zone Promise Neighborhood ...  Yes  NaN  ...
# 1             Robert F. Kennedy Promise Neighborhood  NaN  Yes  ...
# 2                                  E Hoohiki Kaiaulu  Yes  NaN  ...
# 3       Carson Promise Neighborhood - Planning Grant  NaN  NaN  ...
# 4                    Saint Paul Promise Neighborhood  Yes  Yes  ...
#
#                                School2  \
# 0                 Conestoga Elementary
# 1                UCLA Community School
# 2            Molokai High School (PLA)
# 3  Glenn Hammond Curtiss Middle School
# 4                   Jackson Elementary
#
#                                   School3  \
# 0                   Druid Hill Elementary
# 1  Ambassador School for Global Education
# 2                   Molokai Middle School
# 3           Andrew Carnegie Middle School
# 4                                     NaN
#
#                                       School4  \
# 0                           Kellom Elementary
# 1     Ambassador School for Global Leadership
# 2  Kualapu`u Public Conversion Charter School
# 3                   Dolores Street Elementary
# 4                                         NaN
#
#                                School5                              School6  \
# 0                   Kennedy Elementary              King Science Elementary
# 1  Los Angeles High School of the Arts  School for Visual Arts & Humanities
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#               School7              School8  \
# 0  Lothrup Elementary  Franklin Elementary
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
#                                   Additional Schools Grantee  \
# 0                                                NaN     NaN
# 1  These schools (with the exception of the Los A...     NaN
# 2                                                NaN     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                             Location
# 0                     Omaha, NE\n(41.2984, -95.9123)
# 1               Los Angeles, CA\n(34.0595, -118.308)
# 2  Hana on Maui island and Molokai (island wide n...
# 3                    Carson, CA\n(33.8222, -118.264)
# 4                Saint Paul, MN\n(44.9543, -93.1618)
#
# [5 rows x 54 columns]

# %%
def test_create_dataframe (frame, columes):
    if set(frame.columns)!= set(columes):
        print('False, columns do not fit')
        return 
    if len(set(frame.dtypes))>=2:
        print('False, more than 1 type')
        return
    if frame.shape[0]<10:
        print('False, row less then 10')
        return
    print('True')
    return

# %%
test_create_dataframe(gradebook, ['age','midterm','final'])
# Out:
# True
